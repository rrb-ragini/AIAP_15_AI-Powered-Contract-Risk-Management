# %%
import asyncio
import json
from main import run_pipeline

# %%
contract_text = """
INDEMNITY
Vendor shall indemnify and hold harmless the Client from any claims arising from negligence or misconduct.
"""

# %%
result = asyncio.run(run_pipeline(contract_text))
print(json.dumps(result, indent=2))

# %% [markdown]
# [
#   {
#     "clause_id": 1,
#     "clause_text": "...",
#     "golden_clause_detected": true,
#     "golden_clause_type": "Indemnity",
#     "final_risk_score": 7.5,
#     "risk_level": "High",
#     "business_risk_if_ignored": "Exposure to unlimited liability claims.",
#     "suggested_correction": "Introduce liability cap and mutual indemnity.",
#     "justification": "Clause imposes unilateral unlimited indemnity.",
#     "confidence": 0.86
#   }
# ]
